# %%
from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.model_selection import cross_validate
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import get_scorer
from sklearn.base import clone
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from helper import cv_comparison

# Now we will try using SMOTE to oversample the minority class in the training set.
# Same preprocessing as before, but we add SMOTE in now

def SMOTE_preprocessing_fn():
    return [('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.95)),
    ('smote', SMOTE(random_state = 0))]
pipeline = ImbPipeline(steps = SMOTE_preprocessing_fn())
hasattr(pipeline.steps[-1][-1], 'fit_resample')

cv_comparison(SMOTE_preprocessing_fn, X_train, y_train, rskf, 'Only SMOTE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 28
#      25 pipeline = ImbPipeline(steps = SMOTE_preprocessing_fn())
#      26 hasattr(pipeline.steps[-1][-1], 'fit_resample')
# ---> 28 cv_comparison(SMOTE_preprocessing_fn, X_train, y_train, rskf, 'Only SMOTE')
#
# NameError: name 'X_train' is not defined
